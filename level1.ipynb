# %% [markdown]
# <a href="https://colab.research.google.com/github/alisha873/AI-ML/blob/main/level1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#loading the data set
data=pd.read_csv('/content/data.csv')

# %% [markdown]
# #sample image of clothing from each category

# %%
data_array=data.values
unique=np.sort(np.unique(data_array[:,0]))
fig,axs=plt.subplots(1,len(unique),figsize=(12,4))

if len(unique) == 1:
    axs = [axs]

arr=[]
for row in data_array:
    if row[0] in arr:
        continue
    else:
        arr.append(row[0])
        image=row[1:].reshape(28,28)

        ax = axs[list(unique).index(row[0])]
        ax.imshow(image,cmap='gray',interpolation='bicubic')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title("Category " + str(row[0]))

plt.savefig('task1.png',dpi=100)
plt.show()

# %% [markdown]
# #summary statistics

# %%
data_stat=data.iloc[:, 1:].describe()
print(data_stat)
# Out:
#              pixel1        pixel2        pixel3        pixel4        pixel5  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.000900      0.006150      0.035333      0.101933      0.247967
# std        0.094689      0.271011      1.222324      2.452871      4.306912
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max       16.000000     36.000000    226.000000    164.000000    227.000000
#
#              pixel6        pixel7        pixel8        pixel9       pixel10  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.411467      0.805767      2.198283      5.682000     14.488767
# ...
